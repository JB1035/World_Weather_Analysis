# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy as cp

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = cp.nearest_city(coordinate[0], coordinate[1]).city_name 
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 770

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather['weather'][0]['description']
        city_country = city_weather['sys']['country']       
            
        # Append the city information into the city_data list
        city_data.append({'City': city.title(),'Country':city_country,
                          'Lat':city_lat,'Lng':city_lng,
                          'Max Temp':city_max_temp,'Humidity':city_humidity,
                          'Cloudiness':city_clouds,'Wind Speed':city_wind,
                          'Current Description':city_weather_description })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | camacari
# Processing Record 2 of Set 1 | bardiyah
# Processing Record 3 of Set 1 | emerald
# Processing Record 4 of Set 1 | galashiels
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | dutlwe
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | ribeira grande
# Processing Record 16 of Set 1 | chuy
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | cabo san lucas
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | kungurtug
# Processing Record 22 of Set 1 | clyde river
# Processing Record 23 of Set 1 | santa rosa
# Processing Record 24 of Set 1 | bathsheba
# Processing Record 25 of Set 1 | igrim
# Processing Record 26 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 27 of Set 1 | hoquiam
# Processing Record 28 of Set 1 | shimoda
# Processing Record 29 of Set 1 | statesboro
# Processing Record 30 of Set 1 | gari
# Processing Record 31 of Set 1 | pisco
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | lebu
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | poso
# Processing Record 40 of Set 1 | cayenne
# Processing Record 41 of Set 1 | jardim
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | bengkulu
# Processing Record 44 of Set 1 | praya
# Processing Record 45 of Set 1 | dakar
# Processing Record 46 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 1 | key west
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | gimli
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | alofi
# Processing Record 5 of Set 2 | college place
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | bonanza
# Processing Record 8 of Set 2 | mumford
# Processing Record 9 of Set 2 | sao filipe
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | tabas
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | codajas
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | itupiranga
# Processing Record 17 of Set 2 | ahipara
# Processing Record 18 of Set 2 | hauterive
# Processing Record 19 of Set 2 | starokorsunskaya
# Processing Record 20 of Set 2 | nianzishan
# Processing Record 21 of Set 2 | sitka
# Processing Record 22 of Set 2 | saint-augustin
# Processing Record 23 of Set 2 | port macquarie
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | nicoya
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | atuona
# Processing Record 30 of Set 2 | chapais
# Processing Record 31 of Set 2 | cockburn town
# Processing Record 32 of Set 2 | campbell river
# Processing Record 33 of Set 2 | tuatapere
# Processing Record 34 of Set 2 | saldanha
# Processing Record 35 of Set 2 | ponta delgada
# Processing Record 36 of Set 2 | san quintin
# Processing Record 37 of Set 2 | norman wells
# Processing Record 38 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 2 | longyearbyen
# Processing Record 40 of Set 2 | sechura
# Processing Record 41 of Set 2 | brae
# Processing Record 42 of Set 2 | miraflores
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | los llanos de aridane
# Processing Record 46 of Set 2 | pauini
# Processing Record 47 of Set 2 | fortuna
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | hovd
# Processing Record 50 of Set 2 | westport
# Processing Record 1 of Set 3 | grindavik
# Processing Record 2 of Set 3 | mataura
# Processing Record 3 of Set 3 | bilma
# Processing Record 4 of Set 3 | san patricio
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 3 | port blair
# Processing Record 8 of Set 3 | jaguarao
# Processing Record 9 of Set 3 | coos bay
# Processing Record 10 of Set 3 | kilindoni
# Processing Record 11 of Set 3 | northam
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | ola
# Processing Record 15 of Set 3 | nyaunglebin
# Processing Record 16 of Set 3 | riyadh
# Processing Record 17 of Set 3 | imeni zhelyabova
# Processing Record 18 of Set 3 | aragarcas
# Processing Record 19 of Set 3 | guerrero negro
# Processing Record 20 of Set 3 | rio gallegos
# Processing Record 21 of Set 3 | douglas
# Processing Record 22 of Set 3 | tarauaca
# Processing Record 23 of Set 3 | ballina
# Processing Record 24 of Set 3 | alta floresta
# Processing Record 25 of Set 3 | malanje
# Processing Record 26 of Set 3 | caravelas
# Processing Record 27 of Set 3 | albany
# Processing Record 28 of Set 3 | ferkessedougou
# Processing Record 29 of Set 3 | port hueneme
# Processing Record 30 of Set 3 | hasaki
# Processing Record 31 of Set 3 | esperance
# Processing Record 32 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 3 | olafsvik
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | bethel
# Processing Record 36 of Set 3 | souillac
# Processing Record 37 of Set 3 | smoky lake
# Processing Record 38 of Set 3 | ntcheu
# Processing Record 39 of Set 3 | dingle
# Processing Record 40 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 41 of Set 3 | necochea
# Processing Record 42 of Set 3 | longyan
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | hualmay
# Processing Record 45 of Set 3 | sakaiminato
# Processing Record 46 of Set 3 | takaka
# Processing Record 47 of Set 3 | luderitz
# Processing Record 48 of Set 3 | severnyy
# Processing Record 49 of Set 3 | kamenka
# Processing Record 50 of Set 3 | yellowknife
# Processing Record 1 of Set 4 | gamba
# Processing Record 2 of Set 4 | vanavara
# Processing Record 3 of Set 4 | changji
# Processing Record 4 of Set 4 | ixtapa
# Processing Record 5 of Set 4 | pangai
# Processing Record 6 of Set 4 | barguzin
# Processing Record 7 of Set 4 | broken hill
# Processing Record 8 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 4 | hobyo
# Processing Record 10 of Set 4 | falkenberg
# Processing Record 11 of Set 4 | yulara
# Processing Record 12 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 13 of Set 4 | gushi
# Processing Record 14 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 4 | north bend
# Processing Record 16 of Set 4 | genhe
# Processing Record 17 of Set 4 | kandi
# Processing Record 18 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 4 | nuuk
# Processing Record 20 of Set 4 | hervey bay
# Processing Record 21 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 4 | klaksvik
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | port alfred
# Processing Record 25 of Set 4 | acarau
# Processing Record 26 of Set 4 | kruisfontein
# Processing Record 27 of Set 4 | victor harbor
# Processing Record 28 of Set 4 | santiago del estero
# Processing Record 29 of Set 4 | ler
# Processing Record 30 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | barrow
# Processing Record 33 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 4 | broome
# Processing Record 35 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 4 | helong
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | mount isa
# Processing Record 39 of Set 4 | cap malheureux
# Processing Record 40 of Set 4 | popondetta
# Processing Record 41 of Set 4 | carnarvon
# Processing Record 42 of Set 4 | amapa
# Processing Record 43 of Set 4 | kieta
# Processing Record 44 of Set 4 | marzuq
# Processing Record 45 of Set 4 | mutata
# Processing Record 46 of Set 4 | half moon bay
# Processing Record 47 of Set 4 | severo-kurilsk
# Processing Record 48 of Set 4 | bousse
# Processing Record 49 of Set 4 | progreso
# Processing Record 50 of Set 4 | ialibu
# Processing Record 1 of Set 5 | vysokogornyy
# Processing Record 2 of Set 5 | kaeo
# Processing Record 3 of Set 5 | nampa
# Processing Record 4 of Set 5 | kutum
# Processing Record 5 of Set 5 | orlik
# Processing Record 6 of Set 5 | rach gia
# Processing Record 7 of Set 5 | luangwa
# Processing Record 8 of Set 5 | kavieng
# Processing Record 9 of Set 5 | yeppoon
# Processing Record 10 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 5 | airai
# Processing Record 12 of Set 5 | ambon
# Processing Record 13 of Set 5 | pangnirtung
# Processing Record 14 of Set 5 | ilulissat
# Processing Record 15 of Set 5 | otradnoye
# Processing Record 16 of Set 5 | sao jose da coroa grande
# Processing Record 17 of Set 5 | kostomuksha
# Processing Record 18 of Set 5 | castro
# Processing Record 19 of Set 5 | coahuayana
# Processing Record 20 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 5 | yarmouth
# Processing Record 22 of Set 5 | aksaray
# Processing Record 23 of Set 5 | aklavik
# Processing Record 24 of Set 5 | naryan-mar
# Processing Record 25 of Set 5 | massakory
# Processing Record 26 of Set 5 | omboue
# Processing Record 27 of Set 5 | mar del plata
# Processing Record 28 of Set 5 | sola
# Processing Record 29 of Set 5 | madanapalle
# Processing Record 30 of Set 5 | flinders
# Processing Record 31 of Set 5 | sayyan
# Processing Record 32 of Set 5 | teya
# Processing Record 33 of Set 5 | victoria
# Processing Record 34 of Set 5 | erzin
# Processing Record 35 of Set 5 | torrington
# Processing Record 36 of Set 5 | vestmanna
# Processing Record 37 of Set 5 | charters towers
# Processing Record 38 of Set 5 | vostok
# Processing Record 39 of Set 5 | taganak
# Processing Record 40 of Set 5 | betioky
# Processing Record 41 of Set 5 | coxim
# Processing Record 42 of Set 5 | bredasdorp
# Processing Record 43 of Set 5 | whitehorse
# Processing Record 44 of Set 5 | el tigre
# Processing Record 45 of Set 5 | kirakira
# Processing Record 46 of Set 5 | marsa matruh
# Processing Record 47 of Set 5 | sambava
# Processing Record 48 of Set 5 | saint-denis
# Processing Record 49 of Set 5 | olden
# Processing Record 50 of Set 5 | banda aceh
# Processing Record 1 of Set 6 | makakilo city
# Processing Record 2 of Set 6 | camocim
# Processing Record 3 of Set 6 | hamilton
# Processing Record 4 of Set 6 | asau
# Processing Record 5 of Set 6 | alcantara
# Processing Record 6 of Set 6 | gander
# Processing Record 7 of Set 6 | tete
# Processing Record 8 of Set 6 | scottsbluff
# Processing Record 9 of Set 6 | sompeta
# Processing Record 10 of Set 6 | leningradskiy
# Processing Record 11 of Set 6 | aksu
# Processing Record 12 of Set 6 | bundaberg
# Processing Record 13 of Set 6 | kuytun
# Processing Record 14 of Set 6 | codrington
# Processing Record 15 of Set 6 | solnechnyy
# Processing Record 16 of Set 6 | sur
# Processing Record 17 of Set 6 | kavaratti
# Processing Record 18 of Set 6 | myrhorod
# Processing Record 19 of Set 6 | bairiki
# Processing Record 20 of Set 6 | samarai
# Processing Record 21 of Set 6 | altay
# Processing Record 22 of Set 6 | mitsamiouli
# Processing Record 23 of Set 6 | vitim
# Processing Record 24 of Set 6 | altamont
# Processing Record 25 of Set 6 | ugoofaaru
# Processing Record 26 of Set 6 | talnakh
# Processing Record 27 of Set 6 | sorong
# Processing Record 28 of Set 6 | fare
# Processing Record 29 of Set 6 | lasa
# Processing Record 30 of Set 6 | tiksi
# Processing Record 31 of Set 6 | hambantota
# Processing Record 32 of Set 6 | pietarsaari
# Processing Record 33 of Set 6 | agadez
# Processing Record 34 of Set 6 | mkushi
# Processing Record 35 of Set 6 | maldonado
# Processing Record 36 of Set 6 | pyapon
# Processing Record 37 of Set 6 | porto novo
# Processing Record 38 of Set 6 | ancud
# Processing Record 39 of Set 6 | troitsko-pechorsk
# Processing Record 40 of Set 6 | acapulco
# Processing Record 41 of Set 6 | bandarbeyla
# Processing Record 42 of Set 6 | iqaluit
# Processing Record 43 of Set 6 | mehamn
# Processing Record 44 of Set 6 | lubao
# Processing Record 45 of Set 6 | grimari
# City not found. Skipping...
# Processing Record 46 of Set 6 | veraval
# Processing Record 47 of Set 6 | aquiraz
# Processing Record 48 of Set 6 | sao joao da barra
# Processing Record 49 of Set 6 | porto belo
# Processing Record 50 of Set 6 | yashkul
# Processing Record 1 of Set 7 | srandakan
# Processing Record 2 of Set 7 | linxia
# Processing Record 3 of Set 7 | alice springs
# Processing Record 4 of Set 7 | feijo
# Processing Record 5 of Set 7 | touros
# Processing Record 6 of Set 7 | coihaique
# Processing Record 7 of Set 7 | khatanga
# Processing Record 8 of Set 7 | hofn
# Processing Record 9 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 7 | tura
# Processing Record 11 of Set 7 | ternuvate
# Processing Record 12 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 7 | aykhal
# Processing Record 15 of Set 7 | pitimbu
# Processing Record 16 of Set 7 | umm kaddadah
# Processing Record 17 of Set 7 | saint george
# Processing Record 18 of Set 7 | zhuzhou
# Processing Record 19 of Set 7 | kalanguy
# Processing Record 20 of Set 7 | pachino
# Processing Record 21 of Set 7 | pacific grove
# Processing Record 22 of Set 7 | sawakin
# Processing Record 23 of Set 7 | teknaf
# Processing Record 24 of Set 7 | abadiania
# Processing Record 25 of Set 7 | sulina
# Processing Record 26 of Set 7 | salvador
# Processing Record 27 of Set 7 | isangel
# Processing Record 28 of Set 7 | chesley
# Processing Record 29 of Set 7 | eloy
# Processing Record 30 of Set 7 | green river
# Processing Record 31 of Set 7 | nanortalik
# Processing Record 32 of Set 7 | vigrestad
# Processing Record 33 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 7 | katsuura
# Processing Record 35 of Set 7 | vestmannaeyjar
# Processing Record 36 of Set 7 | bud
# Processing Record 37 of Set 7 | lavrentiya
# Processing Record 38 of Set 7 | pangody
# Processing Record 39 of Set 7 | nepalganj
# City not found. Skipping...
# Processing Record 40 of Set 7 | kokopo
# Processing Record 41 of Set 7 | warrington
# Processing Record 42 of Set 7 | port-gentil
# Processing Record 43 of Set 7 | zhezkazgan
# Processing Record 44 of Set 7 | cherskiy
# Processing Record 45 of Set 7 | greenville
# Processing Record 46 of Set 7 | oktyabrskoye
# Processing Record 47 of Set 7 | lianyuan
# Processing Record 48 of Set 7 | burgeo
# Processing Record 49 of Set 7 | toging
# City not found. Skipping...
# Processing Record 50 of Set 7 | krasnoselkup
# Processing Record 1 of Set 8 | puerto escondido
# Processing Record 2 of Set 8 | powell river
# Processing Record 3 of Set 8 | cabedelo
# Processing Record 4 of Set 8 | nancha
# Processing Record 5 of Set 8 | adrar
# Processing Record 6 of Set 8 | axim
# Processing Record 7 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 8 | champaign
# Processing Record 9 of Set 8 | opuwo
# Processing Record 10 of Set 8 | smithers
# Processing Record 11 of Set 8 | panjab
# Processing Record 12 of Set 8 | mujiayingzi
# Processing Record 13 of Set 8 | ruteng
# Processing Record 14 of Set 8 | norrkoping
# Processing Record 15 of Set 8 | havre-saint-pierre
# Processing Record 16 of Set 8 | ust-nera
# Processing Record 17 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 8 | ylivieska
# Processing Record 19 of Set 8 | gornopravdinsk
# Processing Record 20 of Set 8 | takoradi
# Processing Record 21 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 8 | bistret
# Processing Record 23 of Set 8 | ayan
# Processing Record 24 of Set 8 | bilecik
# Processing Record 25 of Set 8 | evensk
# Processing Record 26 of Set 8 | yongan
# Processing Record 27 of Set 8 | oriximina
# Processing Record 28 of Set 8 | upata
# Processing Record 29 of Set 8 | guryevsk
# Processing Record 30 of Set 8 | lackawanna
# Processing Record 31 of Set 8 | nishihara
# Processing Record 32 of Set 8 | lamu
# Processing Record 33 of Set 8 | arraial do cabo
# Processing Record 34 of Set 8 | torbay
# Processing Record 35 of Set 8 | vardo
# Processing Record 36 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 8 | zhigansk
# Processing Record 38 of Set 8 | muisne
# Processing Record 39 of Set 8 | belyy yar
# Processing Record 40 of Set 8 | matay
# Processing Record 41 of Set 8 | portland
# Processing Record 42 of Set 8 | west bay
# Processing Record 43 of Set 8 | puerto madryn
# Processing Record 44 of Set 8 | nurota
# Processing Record 45 of Set 8 | jalu
# Processing Record 46 of Set 8 | biak
# Processing Record 47 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 8 | skjervoy
# Processing Record 49 of Set 8 | khandyga
# Processing Record 50 of Set 8 | almenara
# Processing Record 1 of Set 9 | imbituba
# Processing Record 2 of Set 9 | frankfort
# Processing Record 3 of Set 9 | barinas
# Processing Record 4 of Set 9 | ankpa
# Processing Record 5 of Set 9 | borovskoy
# Processing Record 6 of Set 9 | ryazhsk
# Processing Record 7 of Set 9 | viedma
# Processing Record 8 of Set 9 | golden
# Processing Record 9 of Set 9 | mikhaylovskoye
# Processing Record 10 of Set 9 | chor
# Processing Record 11 of Set 9 | hearst
# Processing Record 12 of Set 9 | mount gambier
# Processing Record 13 of Set 9 | farmington
# Processing Record 14 of Set 9 | ahuimanu
# Processing Record 15 of Set 9 | kununurra
# Processing Record 16 of Set 9 | nieuw amsterdam
# Processing Record 17 of Set 9 | chinhoyi
# Processing Record 18 of Set 9 | oksfjord
# Processing Record 19 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 9 | santa maria
# Processing Record 21 of Set 9 | kerema
# Processing Record 22 of Set 9 | ransang
# Processing Record 23 of Set 9 | usta muhammad
# Processing Record 24 of Set 9 | nelson bay
# Processing Record 25 of Set 9 | palmer
# Processing Record 26 of Set 9 | dubbo
# Processing Record 27 of Set 9 | macamic
# Processing Record 28 of Set 9 | burica
# City not found. Skipping...
# Processing Record 29 of Set 9 | sisimiut
# Processing Record 30 of Set 9 | lompoc
# Processing Record 31 of Set 9 | glamoc
# Processing Record 32 of Set 9 | hashtrud
# Processing Record 33 of Set 9 | port hardy
# Processing Record 34 of Set 9 | kovdor
# Processing Record 35 of Set 9 | iskateley
# Processing Record 36 of Set 9 | marovoay
# Processing Record 37 of Set 9 | mackenzie
# Processing Record 38 of Set 9 | phalodi
# Processing Record 39 of Set 9 | kushima
# Processing Record 40 of Set 9 | mecca
# Processing Record 41 of Set 9 | quelimane
# Processing Record 42 of Set 9 | ishinomaki
# Processing Record 43 of Set 9 | kundarki
# City not found. Skipping...
# Processing Record 44 of Set 9 | nemuro
# Processing Record 45 of Set 9 | itigi
# Processing Record 46 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 9 | krasnooktyabrskiy
# Processing Record 48 of Set 9 | sioux lookout
# Processing Record 49 of Set 9 | poyarkovo
# Processing Record 50 of Set 9 | cehegin
# Processing Record 1 of Set 10 | bubaque
# Processing Record 2 of Set 10 | shahrud
# Processing Record 3 of Set 10 | sharjah
# Processing Record 4 of Set 10 | ostrovnoy
# Processing Record 5 of Set 10 | nola
# Processing Record 6 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 10 | beringovskiy
# Processing Record 8 of Set 10 | suez
# Processing Record 9 of Set 10 | sembe
# Processing Record 10 of Set 10 | wamba
# Processing Record 11 of Set 10 | atherton
# Processing Record 12 of Set 10 | laguna
# Processing Record 13 of Set 10 | kloulklubed
# Processing Record 14 of Set 10 | araouane
# Processing Record 15 of Set 10 | tupaciguara
# Processing Record 16 of Set 10 | ajdabiya
# Processing Record 17 of Set 10 | salalah
# Processing Record 18 of Set 10 | fayetteville
# Processing Record 19 of Set 10 | wilmington
# Processing Record 20 of Set 10 | qaqortoq
# Processing Record 21 of Set 10 | san jeronimo
# Processing Record 22 of Set 10 | arawa
# Processing Record 23 of Set 10 | erhlin
# City not found. Skipping...
# Processing Record 24 of Set 10 | chatra
# Processing Record 25 of Set 10 | barra do corda
# Processing Record 26 of Set 10 | rawson
# Processing Record 27 of Set 10 | itoman
# Processing Record 28 of Set 10 | kijang
# Processing Record 29 of Set 10 | nichinan
# Processing Record 30 of Set 10 | hvolsvollur
# Processing Record 31 of Set 10 | greenlaw
# Processing Record 32 of Set 10 | karratha
# Processing Record 33 of Set 10 | zalantun
# Processing Record 34 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 35 of Set 10 | helena
# Processing Record 36 of Set 10 | penzance
# Processing Record 37 of Set 10 | conakry
# Processing Record 38 of Set 10 | xining
# Processing Record 39 of Set 10 | irricana
# Processing Record 40 of Set 10 | jaen
# Processing Record 41 of Set 10 | gat
# Processing Record 42 of Set 10 | coronado
# Processing Record 43 of Set 10 | deputatskiy
# Processing Record 44 of Set 10 | capao bonito
# Processing Record 45 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 46 of Set 10 | kattivakkam
# Processing Record 47 of Set 10 | murovane
# Processing Record 48 of Set 10 | san cristobal
# Processing Record 49 of Set 10 | kidal
# Processing Record 50 of Set 10 | great yarmouth
# Processing Record 1 of Set 11 | shakiso
# Processing Record 2 of Set 11 | wageningen
# Processing Record 3 of Set 11 | yichang
# Processing Record 4 of Set 11 | sartell
# Processing Record 5 of Set 11 | luganville
# Processing Record 6 of Set 11 | komsomolskiy
# Processing Record 7 of Set 11 | jhang
# Processing Record 8 of Set 11 | dutse
# Processing Record 9 of Set 11 | semey
# Processing Record 10 of Set 11 | narsaq
# Processing Record 11 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 12 of Set 11 | coquimbo
# Processing Record 13 of Set 11 | colares
# Processing Record 14 of Set 11 | berdigestyakh
# Processing Record 15 of Set 11 | sabha
# Processing Record 16 of Set 11 | morgan city
# Processing Record 17 of Set 11 | toktogul
# Processing Record 18 of Set 11 | tromso
# Processing Record 19 of Set 11 | sibolga
# Processing Record 20 of Set 11 | itaituba
# Processing Record 21 of Set 11 | ridgecrest
# Processing Record 22 of Set 11 | college
# Processing Record 23 of Set 11 | pudozh
# Processing Record 24 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 11 | akyab
# Processing Record 26 of Set 11 | maromitsa
# Processing Record 27 of Set 11 | sterling
# Processing Record 28 of Set 11 | berlevag
# Processing Record 29 of Set 11 | yatou
# Processing Record 30 of Set 11 | doha
# Processing Record 31 of Set 11 | gaoual
# Processing Record 32 of Set 11 | neiafu
# Processing Record 33 of Set 11 | zyryanka
# Processing Record 34 of Set 11 | muros
# Processing Record 35 of Set 11 | darhan
# Processing Record 36 of Set 11 | husavik
# Processing Record 37 of Set 11 | san javier
# Processing Record 38 of Set 11 | neuquen
# Processing Record 39 of Set 11 | mnogovershinnyy
# Processing Record 40 of Set 11 | bilibino
# Processing Record 41 of Set 11 | paamiut
# Processing Record 42 of Set 11 | ramasukha
# City not found. Skipping...
# Processing Record 43 of Set 11 | piranhas
# Processing Record 44 of Set 11 | nishiwaki
# Processing Record 45 of Set 11 | urumqi
# Processing Record 46 of Set 11 | vila franca do campo
# Processing Record 47 of Set 11 | sao geraldo do araguaia
# Processing Record 48 of Set 11 | maragogi
# Processing Record 49 of Set 11 | bereda
# Processing Record 50 of Set 11 | bay roberts
# Processing Record 1 of Set 12 | chimbarongo
# Processing Record 2 of Set 12 | nabire
# Processing Record 3 of Set 12 | xuddur
# Processing Record 4 of Set 12 | sept-iles
# Processing Record 5 of Set 12 | roma
# Processing Record 6 of Set 12 | poum
# Processing Record 7 of Set 12 | ukiah
# Processing Record 8 of Set 12 | qobustan
# Processing Record 9 of Set 12 | stokmarknes
# Processing Record 10 of Set 12 | hami
# Processing Record 11 of Set 12 | ponte nova
# Processing Record 12 of Set 12 | walvis bay
# Processing Record 13 of Set 12 | arlit
# Processing Record 14 of Set 12 | saint-pierre
# Processing Record 15 of Set 12 | verkhnevilyuysk
# Processing Record 16 of Set 12 | cervo
# Processing Record 17 of Set 12 | bayir
# Processing Record 18 of Set 12 | vung tau
# Processing Record 19 of Set 12 | durusu
# Processing Record 20 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 21 of Set 12 | sokoto
# Processing Record 22 of Set 12 | kochki
# Processing Record 23 of Set 12 | saint-louis
# Processing Record 24 of Set 12 | faratsiho
# Processing Record 25 of Set 12 | tacotalpa
# Processing Record 26 of Set 12 | kalmunai
# Processing Record 27 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 12 | chiusi
# Processing Record 29 of Set 12 | dobra
# Processing Record 30 of Set 12 | pochutla
# Processing Record 31 of Set 12 | tuskegee
# Processing Record 32 of Set 12 | caucaia
# Processing Record 33 of Set 12 | la trinidad
# Processing Record 34 of Set 12 | mwinilunga
# Processing Record 35 of Set 12 | yar-sale
# Processing Record 36 of Set 12 | guiratinga
# Processing Record 37 of Set 12 | markova
# Processing Record 38 of Set 12 | cedar city
# Processing Record 39 of Set 12 | sehithwa
# Processing Record 40 of Set 12 | contamana
# Processing Record 41 of Set 12 | chamrajnagar
# Processing Record 42 of Set 12 | champerico
# Processing Record 43 of Set 12 | dong xoai
# Processing Record 44 of Set 12 | moroni
# Processing Record 45 of Set 12 | misratah
# Processing Record 46 of Set 12 | harper
# Processing Record 47 of Set 12 | kibakwe
# Processing Record 48 of Set 12 | isilkul
# Processing Record 49 of Set 12 | jatara
# Processing Record 50 of Set 12 | strzelin
# Processing Record 1 of Set 13 | katsiveli
# City not found. Skipping...
# Processing Record 2 of Set 13 | rio grande
# Processing Record 3 of Set 13 | auki
# Processing Record 4 of Set 13 | henties bay
# Processing Record 5 of Set 13 | tanda
# Processing Record 6 of Set 13 | malindi
# Processing Record 7 of Set 13 | antalaha
# Processing Record 8 of Set 13 | alugan
# Processing Record 9 of Set 13 | kolpashevo
# Processing Record 10 of Set 13 | dzilam gonzalez
# Processing Record 11 of Set 13 | ushtobe
# Processing Record 12 of Set 13 | tsagan aman
# Processing Record 13 of Set 13 | los algarrobos
# Processing Record 14 of Set 13 | sao gabriel da cachoeira
# Processing Record 15 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 16 of Set 13 | aksarka
# Processing Record 17 of Set 13 | calama
# Processing Record 18 of Set 13 | baker city
# Processing Record 19 of Set 13 | wellington
# Processing Record 20 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 13 | hudson bay
# Processing Record 22 of Set 13 | san policarpo
# Processing Record 23 of Set 13 | kencong
# Processing Record 24 of Set 13 | oskarshamn
# Processing Record 25 of Set 13 | lorengau
# Processing Record 26 of Set 13 | ordynskoye
# Processing Record 27 of Set 13 | winterberg
# Processing Record 28 of Set 13 | tawnat
# City not found. Skipping...
# Processing Record 29 of Set 13 | okha
# Processing Record 30 of Set 13 | ereymentau
# Processing Record 31 of Set 13 | yokadouma
# Processing Record 32 of Set 13 | fujieda
# Processing Record 33 of Set 13 | orsha
# Processing Record 34 of Set 13 | uthal
# Processing Record 35 of Set 13 | starodubskoye
# Processing Record 36 of Set 13 | itarema
# Processing Record 37 of Set 13 | maragogipe
# Processing Record 38 of Set 13 | liberal
# Processing Record 39 of Set 13 | comodoro rivadavia
# Processing Record 40 of Set 13 | praia
# Processing Record 41 of Set 13 | gidam
# Processing Record 42 of Set 13 | lephepe
# City not found. Skipping...
# Processing Record 43 of Set 13 | khasan
# Processing Record 44 of Set 13 | nacogdoches
# Processing Record 45 of Set 13 | yerbogachen
# Processing Record 46 of Set 13 | linhares
# Processing Record 47 of Set 13 | chicama
# Processing Record 48 of Set 13 | anantapur
# Processing Record 49 of Set 13 | rocha
# Processing Record 50 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 14 | tsabong
# Processing Record 2 of Set 14 | chipinge
# Processing Record 3 of Set 14 | naze
# Processing Record 4 of Set 14 | bossier city
# Processing Record 5 of Set 14 | khurianwala
# City not found. Skipping...
# Processing Record 6 of Set 14 | horki
# Processing Record 7 of Set 14 | perambalur
# Processing Record 8 of Set 14 | grand island
# Processing Record 9 of Set 14 | tabou
# Processing Record 10 of Set 14 | salinas
# Processing Record 11 of Set 14 | tarko-sale
# Processing Record 12 of Set 14 | hvide sande
# Processing Record 13 of Set 14 | arman
# Processing Record 14 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 15 of Set 14 | manggar
# Processing Record 16 of Set 14 | lagoa
# Processing Record 17 of Set 14 | yamada
# Processing Record 18 of Set 14 | bac lieu
# Processing Record 19 of Set 14 | hirara
# Processing Record 20 of Set 14 | trat
# Processing Record 21 of Set 14 | tianpeng
# Processing Record 22 of Set 14 | rathdrum
# Processing Record 23 of Set 14 | la joya
# Processing Record 24 of Set 14 | batemans bay
# Processing Record 25 of Set 14 | honningsvag
# Processing Record 26 of Set 14 | nouadhibou
# Processing Record 27 of Set 14 | rosarito
# Processing Record 28 of Set 14 | businga
# Processing Record 29 of Set 14 | trairi
# Processing Record 30 of Set 14 | urucui
# Processing Record 31 of Set 14 | constitucion
# Processing Record 32 of Set 14 | bougouni
# Processing Record 33 of Set 14 | mayo
# Processing Record 34 of Set 14 | mizdah
# Processing Record 35 of Set 14 | predivinsk
# Processing Record 36 of Set 14 | manokwari
# Processing Record 37 of Set 14 | bani
# Processing Record 38 of Set 14 | kyra
# Processing Record 39 of Set 14 | daru
# Processing Record 40 of Set 14 | virginia beach
# Processing Record 41 of Set 14 | mackay
# Processing Record 42 of Set 14 | evanston
# Processing Record 43 of Set 14 | gotsu
# Processing Record 44 of Set 14 | maputo
# Processing Record 45 of Set 14 | bheramara
# Processing Record 46 of Set 14 | lexington
# Processing Record 47 of Set 14 | farroupilha
# Processing Record 48 of Set 14 | maumere
# Processing Record 49 of Set 14 | manaure
# Processing Record 50 of Set 14 | znamenskoye
# Processing Record 1 of Set 15 | palafrugell
# Processing Record 2 of Set 15 | piste
# Processing Record 3 of Set 15 | tongsa
# City not found. Skipping...
# Processing Record 4 of Set 15 | dodge city
# Processing Record 5 of Set 15 | saint anthony
# Processing Record 6 of Set 15 | stornoway
# Processing Record 7 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 15 | praia da vitoria
# Processing Record 9 of Set 15 | conde
# Processing Record 10 of Set 15 | phon
# Processing Record 11 of Set 15 | aitape
# Processing Record 12 of Set 15 | manzanillo
# Processing Record 13 of Set 15 | oum hadjer
# Processing Record 14 of Set 15 | nizhneudinsk
# Processing Record 15 of Set 15 | maniitsoq
# Processing Record 16 of Set 15 | meulaboh
# Processing Record 17 of Set 15 | fairmount
# Processing Record 18 of Set 15 | vienna
# Processing Record 19 of Set 15 | terrace
# Processing Record 20 of Set 15 | vila
# Processing Record 21 of Set 15 | soyo
# Processing Record 22 of Set 15 | nan
# Processing Record 23 of Set 15 | biltine
# Processing Record 24 of Set 15 | sistranda
# Processing Record 25 of Set 15 | haverfordwest
# Processing Record 26 of Set 15 | copiapo
# Processing Record 27 of Set 15 | magdalena
# Processing Record 28 of Set 15 | belmonte
# Processing Record 29 of Set 15 | tucumcari
# Processing Record 30 of Set 15 | fairbanks
# Processing Record 31 of Set 15 | sinfra
# Processing Record 32 of Set 15 | qingan
# City not found. Skipping...
# Processing Record 33 of Set 15 | grand-lahou
# Processing Record 34 of Set 15 | cuicatlan
# Processing Record 35 of Set 15 | gizo
# Processing Record 36 of Set 15 | alappuzha
# Processing Record 37 of Set 15 | marienburg
# Processing Record 38 of Set 15 | noumea
# Processing Record 39 of Set 15 | bonthe
# Processing Record 40 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 41 of Set 15 | kismayo
# Processing Record 42 of Set 15 | rantauprapat
# Processing Record 43 of Set 15 | te anau
# Processing Record 44 of Set 15 | geraldton
# Processing Record 45 of Set 15 | marsh harbour
# Processing Record 46 of Set 15 | barranca
# Processing Record 47 of Set 15 | kupang
# Processing Record 48 of Set 15 | korla
# Processing Record 49 of Set 15 | nioro
# Processing Record 50 of Set 15 | straldza
# City not found. Skipping...
# Processing Record 1 of Set 16 | wanning
# Processing Record 2 of Set 16 | russell
# Processing Record 3 of Set 16 | kailua
# Processing Record 4 of Set 16 | kasongo-lunda
# Processing Record 5 of Set 16 | bogotol
# Processing Record 6 of Set 16 | labuhan
# Processing Record 7 of Set 16 | byron bay
# Processing Record 8 of Set 16 | shirokiy
# Processing Record 9 of Set 16 | sylva
# Processing Record 10 of Set 16 | shenjiamen
# Processing Record 11 of Set 16 | chemodanovka
# Processing Record 12 of Set 16 | kasongo
# Processing Record 13 of Set 16 | roald
# Processing Record 14 of Set 16 | port-cartier
# Processing Record 15 of Set 16 | kavarna
# Processing Record 16 of Set 16 | seoul
# Processing Record 17 of Set 16 | kachiry
# Processing Record 18 of Set 16 | yarada
# Processing Record 19 of Set 16 | stamsund
# City not found. Skipping...
# Processing Record 20 of Set 16 | stephenville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 712

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Camacari      BR -12.6975  -38.3242     82.17        80          71
# 1      Bardiyah      LY  31.7561   25.0865     65.88        64           0
# 2       Emerald      AU -23.5333  148.1667     68.34        40          86
# 3    Galashiels      GB  55.6146   -2.8070     37.53        91          84
# 4  Punta Arenas      CL -53.1500  -70.9167     64.51        45           0
# 5        Kodiak      US  57.7900 -152.4072     36.91        65         100
# 6    Nikolskoye      RU  59.7035   30.7861     26.49        81         100
# 7       Ushuaia      AR -54.8000  -68.3000     62.22        55          75
# 8        Dutlwe      BW -23.9833   23.9000     83.23        28          69
# 9     Busselton      AU -33.6500  115.3333     61.02        79           3
#
#    Wind Speed Current Description
# 0        7.07       broken clouds
# 1        7.87           clear sky
# 2       13.18     overcast clouds
# 3        2.55       broken clouds
# 4       26.46           clear sky
# 5       13.80     overcast clouds
# 6        6.89     overcast clouds
# 7       10.36       moderate rain
# 8        3.80       broken clouds
# 9        7.94           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity","Cloudiness","Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Camacari      BR -12.6975  -38.3242     82.17        80          71
# 1      Bardiyah      LY  31.7561   25.0865     65.88        64           0
# 2       Emerald      AU -23.5333  148.1667     68.34        40          86
# 3    Galashiels      GB  55.6146   -2.8070     37.53        91          84
# 4  Punta Arenas      CL -53.1500  -70.9167     64.51        45           0
# 5        Kodiak      US  57.7900 -152.4072     36.91        65         100
# 6    Nikolskoye      RU  59.7035   30.7861     26.49        81         100
# 7       Ushuaia      AR -54.8000  -68.3000     62.22        55          75
# 8        Dutlwe      BW -23.9833   23.9000     83.23        28          69
# 9     Busselton      AU -33.6500  115.3333     61.02        79           3
#
#    Wind Speed Current Description
# 0        7.07       broken clouds
# 1        7.87           clear sky
# 2       13.18     overcast clouds
# 3        2.55       broken clouds
# 4       26.46           clear sky
# 5       13.80     overcast clouds
# 6        6.89     overcast clouds
# 7       10.36       moderate rain
# 8        3.80       broken clouds
# 9        7.94           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
